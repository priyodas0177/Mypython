# %%
car={
    "brand": "toyota",
    "model": "corolla",
    "year": "1995"

}
x=car["model"]
print(x)
# Out:
# corolla

# %% [markdown]
# # how to access

# %%
x=car.get("brand")
print(x)
# Out:
# toyota

# %% [markdown]
# # he keys() method will return a list of all the keys in the dictionary.

# %%
x=car.keys()
print(x)
# Out:
# dict_keys(['brand', 'model', 'year'])

# %% [markdown]
# # Add items

# %%
car={
    "brand": "toyota",
    "model": "corolla",
    "year": "1995"

}
x=car.keys()
car["color"]="red"
print(x)
# Out:
# dict_keys(['brand', 'model', 'year', 'color'])

# %%
x=car.values()
print(x)
# Out:
# dict_values(['toyota', 'corolla', '1995', 'red'])

# %% [markdown]
# # Change Values

# %%
car={
    "brand": "toyota",
    "model": "corolla",
    "year": "1995"

}
car["brand"]="BMW"

print(car)
# Out:
# {'brand': 'BMW', 'model': 'corolla', 'year': '1995'}

# %% [markdown]
# # value update

# %%
car={
    "brand": "toyota",
    "model": "corolla",
    "year": "1995"

}
car["brand"]="BMW"

print(car)
