# %%
input=float(input("Enter a number: "))
if input>=90:
    print("A+")
elif input>=85:
    print("A")
elif input>=80:
    print("B+")
elif input>=75:
    print("B")
elif input>=70:
    print("C+")

elif input>=65:
    print("C")

elif input>=60:
    print("D+")

elif input>=50:

    print("D")
else:
    print("Fail")
# Out:
# B

# %%
age=int(input("Enter your age:"))
has_license=True
if age>=18:
    if has_license:
        print("you can drive a car ")
    elif not has_license:
        print("you need a license ")
else:
    print("you are too young")
# Out:
# you can drive a car

# %%
store_uname="priyo"
store_pass="priyo123"

uname=input("Enter a name: ")
password=input("enter password: ")
is_action=True
if uname == store_uname and password == store_pass:
        if is_action:
            print("login successfull")
        else:
            print("login failed")
else:
    print("invalid user")
# Out:
# login successfull

# %% [markdown]
# # Match
